# %%
import cv2
import numpy as np
# import cmapy
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/datasets/home/memmel/PointNav-VO/imgs_attention_heads/base_in21k_trained/img_norm_27_act_1/img.png')
attn = cv2.imread('/datasets/home/memmel/PointNav-VO/imgs_attention_heads/base_in21k_trained/img_norm_9_act_3/attn-heads-sum.png')

# %%
img = plt.imread('/datasets/home/memmel/PointNav-VO/imgs_attention_heads/base_in21k_trained/img_10_act_2/img_resized.png')
attn = plt.imread('/datasets/home/memmel/PointNav-VO/imgs_attention_heads/base_in21k_trained/img_10_act_2/attn-heads-sum.png')

# %%
img = np.array(img*255., dtype=np.uint8)
attn = np.array(attn*255., dtype=np.uint8)

# %%
plt.imshow(img)

# %%
plt.imshow(attn)

# %%
attn.shape, img.shape
# Out:
# ((336, 192, 4), (336, 192, 4))

# %%
fin = cv2.addWeighted(attn, 0.8, img, 0.6, 0.0)
plt.imshow(fin)
